# %% [markdown]
# # Ejercicio 10: Re-ranking
#
# ## Darlin Anacicha    Curso: GR1CC
#
# **Objetivo:** Implementar y evaluar un pipeline de Recuperación de Información en dos etapas, y analizar el impacto del re-ranking en la calidad del ranking.
#
# ## Parte 1. Preparación del corpus
#
# * Cargar el corpus (documentos/pasajes).
# * Cargar las consultas (queries).
# * Cargar qrels (relevancia).

# %%
# !pip install beir
# Out:
# Requirement already satisfied: beir in /usr/local/lib/python3.12/dist-packages (2.2.0)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (from beir) (5.1.1)
# Requirement already satisfied: pytrec-eval-terrier in /usr/local/lib/python3.12/dist-packages (from beir) (0.5.10)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (from beir) (4.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets->beir) (3.20.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets->beir) (2.0.2)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets->beir) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets->beir) (0.4.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets->beir) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets->beir) (2.32.5)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets->beir) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets->beir) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets->beir) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in /usr/local/lib/python3.12/dist-packages (from datasets->beir) (0.70.18)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets->beir) (2025.10.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from datasets->beir) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets->beir) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets->beir) (6.0.3)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from pytrec-eval-terrier->beir) (1.15.3)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers->beir) (4.57.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers->beir) (2.8.0+cu126)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from sentence-transformers->beir) (1.6.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from sentence-transformers->beir) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers->beir) (4.15.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets->beir) (3.13.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets->beir) (4.12.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets->beir) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets->beir) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets->beir) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets->beir) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.25.0->datasets->beir) (1.2.1rc0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets->beir) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets->beir) (2.6.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (3.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers->beir) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers->beir) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers->beir) (0.6.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets->beir) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets->beir) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets->beir) (2025.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers->beir) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers->beir) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets->beir) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets->beir) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets->beir) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets->beir) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets->beir) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets->beir) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets->beir) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets->beir) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers->beir) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers->beir) (3.0.3)

# %%
from beir import util
from beir.datasets.data_loader import GenericDataLoader
import pandas as pd

# %%
DATASET_NAME = "scifact"
DATA_DIR = "../data/beir_datasets"
url = f"https://public.ukp.informatik.tu-darmstadt.de/thakur/BEIR/datasets/{DATASET_NAME}.zip"
util.download_and_unzip(url, DATA_DIR)
# Out:
# '../data/beir_datasets/scifact'

# %%
dataset_path = DATA_DIR + "/" + DATASET_NAME
corpus, queries, qrels = GenericDataLoader(dataset_path).load(split="test")
# Out:
#   0%|          | 0/5183 [00:00<?, ?it/s]

# %%
df_corpus = (
    pd.DataFrame.from_dict(corpus, orient="index")
      .reset_index()
      .rename(columns={"index": "doc_id"})
)

df_corpus
# Out:
#          doc_id                                               text  \
# 0          4983  Alterations of the architecture of cerebral wh...
# 1          5836  Myelodysplastic syndromes (MDS) are age-depend...
# 2          7912  ID elements are short interspersed elements (S...
# 3         18670  DNA methylation plays an important role in bio...
# 4         19238  Two human Golli (for gene expressed in the oli...
# ...         ...                                                ...
# 5178  195689316  BACKGROUND The main associations of body-mass ...
# 5179  195689757  A key aberrant biological difference between t...
# 5180  196664003  A signaling pathway transmits information from...
# 5181  198133135  AIMS Trabecular bone score (TBS) is a surrogat...
# 5182  198309074  Introduction: Among the inflammatory mediators...
#
#                                                   title
# 0     Microstructural development of human newborn c...
# 1     Induction of myelodysplasia by myeloid-derived...
# 2     BC1 RNA, the transcript from a master gene for...
# 3     The DNA Methylome of Human Peripheral Blood Mo...
# 4     The human myelin basic protein gene is include...
# ...                                                 ...
# 5178  Body-mass index and cause-specific mortality i...
# 5179  Targeting metabolic remodeling in glioblastoma...
# 5180  Signaling architectures that transmit unidirec...
# 5181  Association between pre-diabetes, type 2 diabe...
# 5182  Adhesion molecules and chemokines: relation to...
#
# [5183 rows x 3 columns]

# %%
df_queries = (
    pd.DataFrame.from_dict(queries, orient="index", columns=["query"])
      .reset_index()
      .rename(columns={"index": "query_id"})
)

df_queries
# Out:
#     query_id                                              query
# 0          1  0-dimensional biomaterials show inductive prop...
# 1          3  1,000 genomes project enables mapping of genet...
# 2          5         1/2000 in UK have abnormal PrP positivity.
# 3         13  5% of perinatal mortality is due to low birth ...
# 4         36  A deficiency of vitamin B12 increases blood le...
# ..       ...                                                ...
# 295     1379  Women with a higher birth weight are more like...
# 296     1382  aPKCz causes tumour enhancement by affecting g...
# 297     1385   cSMAC formation enhances weak ligand signalling.
# 298     1389  mTORC2 regulates intracellular cysteine levels...
# 299     1395  p16INK4A accumulation is  linked to an abnorma...
#
# [300 rows x 2 columns]

# %%
rows = []
for qid, docs in qrels.items():
    for doc_id, rel in docs.items():
        rows.append({
            "query_id": qid,
            "doc_id": doc_id,
            "relevance": rel
        })

df_qrels = pd.DataFrame(rows)
df_qrels
# Out:
#     query_id    doc_id  relevance
# 0          1  31715818          1
# 1          3  14717500          1
# 2          5  13734012          1
# 3         13   1606628          1
# 4         36   5152028          1
# ..       ...       ...        ...
# 334     1379  17450673          1
# 335     1382  17755060          1
# 336     1385    306006          1
# 337     1389  23895668          1
# 338     1395  17717391          1
#
# [339 rows x 3 columns]

# %%
# Elegimos una query cualquiera que tenga varios documentos relevantes
qid = "133"

print("Query:")
print(df_queries.loc[df_queries["query_id"] == qid, "query"].values[0])

print("\nDocumentos relevantes para esta query:")
df_qrels[(df_qrels["query_id"] == qid) & (df_qrels["relevance"] > 0)]
# Out:
# Query:
# Assembly of invadopodia is triggered by focal generation of phosphatidylinositol-3,4-biphosphate and the activation of the nonreceptor tyrosine kinase Src.
#
# Documentos relevantes para esta query:
#    query_id    doc_id  relevance
# 31      133  38485364          1
# 32      133   6969753          1
# 33      133  17934082          1
# 34      133  16280642          1
# 35      133  12640810          1

# %% [markdown]
# ## Parte 2. Retrieval inicial (baseline)
#
# * Implementar retrieval inicial con BM25
# * Obtener métricas: Recall@10 nDCG@10

# %%
# !pip install rank-bm25

from rank_bm25 import BM25Okapi
import nltk
nltk.download("punkt")
from nltk.tokenize import word_tokenize
# Out:
# Requirement already satisfied: rank-bm25 in /usr/local/lib/python3.12/dist-packages (0.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rank-bm25) (2.0.2)
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Preprocesar corpus
tokenized_corpus = [
    word_tokenize(doc["text"].lower())
    for doc in corpus.values()
]

bm25 = BM25Okapi(tokenized_corpus)
doc_ids = list(corpus.keys())

# %%
def bm25_retrieve(query, top_k=10):
    tokenized_query = word_tokenize(query.lower())
    scores = bm25.get_scores(tokenized_query)
    top_idx = scores.argsort()[::-1][:top_k]
    return [(doc_ids[i], scores[i]) for i in top_idx]

# %%
query_text = queries[qid]
bm25_results = bm25_retrieve(query_text, top_k=10)
bm25_results
# Out:
# [('5270265', np.float64(59.853134662962574)),
#  ('26688294', np.float64(58.67574493391684)),
#  ('45764440', np.float64(58.14946033570541)),
#  ('12785130', np.float64(55.52989817971354)),
#  ('37964706', np.float64(55.02827881096887)),
#  ('9507605', np.float64(53.13107970005058)),
#  ('35884026', np.float64(52.360529973361274)),
#  ('5914739', np.float64(51.94921374614491)),
#  ('10991183', np.float64(50.82883355478484)),
#  ('86694016', np.float64(49.19138716813143))]

# %%
# Solo queries que tienen qrels
valid_queries = {qid: queries[qid] for qid in qrels.keys()}

print("Queries totales:", len(queries))
print("Queries con qrels:", len(valid_queries))
# Out:
# Queries totales: 300
# Queries con qrels: 300

# %%
retrieval_results = {}

for qid_iter, query_text in valid_queries.items():
    bm25_results = bm25_retrieve(query_text, top_k=10)
    retrieval_results[qid_iter] = {
        doc_id: float(score) for doc_id, score in bm25_results
    }

# %%
from beir.retrieval.evaluation import EvaluateRetrieval

evaluator = EvaluateRetrieval()
ndcg, _map, recall, precision = evaluator.evaluate(
    qrels,
    retrieval_results,
    k_values=[10]
)

print("NDCG@10:", ndcg["NDCG@10"])
print("MAP@10:", _map["MAP@10"])
print("Recall@10:", recall["Recall@10"])
print("P@10:", precision["P@10"])
# Out:
# NDCG@10: 0.62006
# MAP@10: 0.57898
# Recall@10: 0.73417
# P@10: 0.08

# %% [markdown]
# ## Parte 3. Implementación del re-ranking _cross-encoder_
#
# * Re-rankear los top-k candidatos para cada query.
# * Identificar qué documentos cambian de posición en el top 10

# %%
from sentence_transformers import CrossEncoder

cross_encoder = CrossEncoder("cross-encoder/ms-marco-MiniLM-L-6-v2")
# Out:
# 2026-01-12 18:39:34.144751: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768243174.403979      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768243174.478678      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768243175.081956      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768243175.081996      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768243175.081999      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768243175.082002      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# config.json:   0%|          | 0.00/794 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]

# %%
pairs = [
    (query_text, corpus[doc_id]["text"])
    for doc_id, _ in bm25_results
]

scores = cross_encoder.predict(pairs)

reranked = sorted(
    zip([doc_id for doc_id, _ in bm25_results], scores),
    key=lambda x: x[1],
    reverse=True
)

reranked
# Out:
# [('18218379', np.float32(-4.296707)),
#  ('13923069', np.float32(-5.0027514)),
#  ('3113630', np.float32(-5.2604175)),
#  ('928281', np.float32(-6.2111826)),
#  ('16630060', np.float32(-7.3663197)),
#  ('7711685', np.float32(-7.4259653)),
#  ('4387484', np.float32(-7.469968)),
#  ('40987633', np.float32(-8.129323)),
#  ('26079071', np.float32(-9.052057)),
#  ('11569583', np.float32(-9.458267))]

# %%
print("BM25 order:")
print([doc for doc, _ in bm25_results])

print("\nCross-Encoder order:")
print([doc for doc, _ in reranked])
# Out:
# BM25 order:
# ['13923069', '928281', '4387484', '18218379', '16630060', '11569583', '26079071', '40987633', '3113630', '7711685']
#
# Cross-Encoder order:
# ['18218379', '13923069', '3113630', '928281', '16630060', '7711685', '4387484', '40987633', '26079071', '11569583']

# %% [markdown]
# ## Parte 4. Implementación del re-ranking _LTR_
#
# * Re-rankear los top-k candidatos para cada query.
# * Identificar qué documentos cambian de posición en el top 10

# %%
X = []
y = []

for qid_iter, query_text in valid_queries.items():
    bm25_results = bm25_retrieve(query_text, top_k=10)

    for doc_id, score in bm25_results:
        X.append([score])
        y.append(
            1 if ((df_qrels["query_id"] == qid_iter) &
                  (df_qrels["doc_id"] == doc_id) &
                  (df_qrels["relevance"] > 0)).any()
            else 0
        )

X = np.array(X)
y = np.array(y)

np.unique(y, return_counts=True)
# Out:
# (array([0, 1]), array([2760,  240]))

# %%
from sklearn.linear_model import LogisticRegression

ltr = LogisticRegression(max_iter=1000)
ltr.fit(X, y)
# Out:
# LogisticRegression(max_iter=1000)

# %%
bm25_results = bm25_retrieve(queries[qid], top_k=10)

X_test = np.array([[score] for _, score in bm25_results])
ltr_scores = ltr.predict_proba(X_test)[:, 1]

ltr_reranked = sorted(
    zip([doc_id for doc_id, _ in bm25_results], ltr_scores),
    key=lambda x: x[1],
    reverse=True
)

ltr_reranked
# Out:
# [('5270265', np.float64(0.2250428164498337)),
#  ('26688294', np.float64(0.21450517800559976)),
#  ('45764440', np.float64(0.20991241262601038)),
#  ('12785130', np.float64(0.18813082950124704)),
#  ('37964706', np.float64(0.18416388503035236)),
#  ('9507605', np.float64(0.16974630498929472)),
#  ('35884026', np.float64(0.16415239601331882)),
#  ('5914739', np.float64(0.16122753155848205)),
#  ('10991183', np.float64(0.15347400503596376)),
#  ('86694016', np.float64(0.14269444770716566))]

# %%
bm25_order = [doc_id for doc_id, _ in bm25_results]
ltr_order = [doc_id for doc_id, _ in ltr_reranked]

print("Ranking BM25:")
for i, doc in enumerate(bm25_order, 1):
    print(f"{i:2d}. {doc}")

print("\nRanking LTR:")
for i, doc in enumerate(ltr_order, 1):
    print(f"{i:2d}. {doc}")
# Out:
# Ranking BM25:
#  1. 5270265
#  2. 26688294
#  3. 45764440
#  4. 12785130
#  5. 37964706
#  6. 9507605
#  7. 35884026
#  8. 5914739
#  9. 10991183
# 10. 86694016
#
# Ranking LTR:
#  1. 5270265
#  2. 26688294
#  3. 45764440
#  4. 12785130
#  5. 37964706
#  6. 9507605
#  7. 35884026
#  8. 5914739
#  9. 10991183
# 10. 86694016

# %% [markdown]
# ## Parte 5. Evaluación post re-ranking
#
# Calcular métricas:
# * nDCG@10
# * MAP
# * Recall@10

# %%
ltr_results_all = {}

for qid, query_text in valid_queries.items():
    bm25_results = bm25_retrieve(query_text, top_k=10)

    X_test = np.array([[score] for _, score in bm25_results])
    ltr_scores = ltr.predict_proba(X_test)[:, 1]

    ltr_results_all[qid] = {
        doc_id: float(score)
        for (doc_id, _), score in zip(bm25_results, ltr_scores)
    }

# %%
ndcg_ltr, map_ltr, recall_ltr, p_ltr = evaluator.evaluate(
    qrels,
    ltr_results_all,
    k_values=[10]
)

print("LTR NDCG@10:", ndcg_ltr["NDCG@10"])
print("LTR MAP@10:", map_ltr["MAP@10"])
print("LTR Recall@10:", recall_ltr["Recall@10"])
# Out:
# LTR NDCG@10: 0.62006
# LTR MAP@10: 0.57898
# LTR Recall@10: 0.73417

# %%
qid_example = list(valid_queries.keys())[0]

bm25_example = bm25_retrieve(valid_queries[qid_example], top_k=10)
X_ex = np.array([[score] for _, score in bm25_example])
ltr_scores_ex = ltr.predict_proba(X_ex)[:, 1]

ltr_example = sorted(
    zip([doc_id for doc_id, _ in bm25_example], ltr_scores_ex),
    key=lambda x: x[1],
    reverse=True
)

print("BM25:", [d for d, _ in bm25_example])
print("LTR :", [d for d, _ in ltr_example])
# Out:
# BM25: ['10931595', '10906636', '12824568', '13231899', '825728', '19651306', '24998637', '42240424', '17518195', '4465608']
# LTR : ['10931595', '10906636', '12824568', '13231899', '825728', '19651306', '24998637', '42240424', '17518195', '4465608']
